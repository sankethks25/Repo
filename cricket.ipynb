# %%
import random
class Bat:  
        
    def sys_bat(self):
        self.run = random.randint(1,6)
        print(self.run)
       
        
    def user_bat(self,run):
        print(run)
        return run
        
class Turn:
    def even_odd(self,user_toss): 
        ball_1 = random.randint(1,6)
        print("your number is :- {}".format(user_toss))
        print('systems number is :- {}'.format(ball_1))

        self.res = user_toss + ball_1

        if self.res % 2 == 0:
            self.result = 'e'
        else:
            self.result = 'o'
        print('the result of two number is:- {}'.format(self.res))
        print('so the toss is :- {}'.format(self.result))                     
    def rest(self):
        return self.result    
    
while True:
    
    print('WELCOME TO CRICKET')
    run_res = 0
    run_res1 = 0
    run_res2 = 0
    run_res3 = 0
    run_res4 = 0
    run_res5 = 0
    usr_bat = Bat()
    system_bat = Bat()
   # test_ball = Ball()
    coin = Turn()
    while True: 
        choice =input('ENTER EVEN OR ODD??: PRESS e/o :- ') 
        if choice[0].lower() == 'e' or choice[0].lower() == 'o':          
            user_toss = int(input('ENTER NUM WITHIN 1 TO 6 :- '))
            coin.even_odd(user_toss) 
            break
        else:
            print('*****ENTER PROPER KEY******')   
       
    if coin.rest() ==  choice:
        
        while True:   
            bat_ball = int(input('WHAT YOU WANT TO CHOOSE BAT OR BALL : 1 for bat 2 for ball '))
            if bat_ball == 1:
        # WHEN USER CHOOSE TO BAT FIRST
                while True:
                    ball_2 = random.randint(1,6)
                    run = int(input('HIT RUN   :- '))
                    print(ball_2)                   
                    run_res += run 
                    print("USER'S TOTAL RUN :- {}".format(run_res))
                    if run == ball_2:
                        print('...........USER WICKET.............')
                #WHEN USER OUT AND B        
                        print("now its system turn to bat ")
                        while True:
                            
                            run = random.randint(1,6)
                            ball_3 = int(input('throw ball :- '))
                            print("system hit :- {}".format(run))
                            run_res1 += run
                            print("systems'S TOTAL RUN :- {}".format(run_res1))
                            if run == ball_3:
                                print('.................SYSTEM WICKET.............')
                                print("END OF THE MATCH")
                                if run_res > run_res1:
                                    print(' $$$$$$$ USER WON THE MATCH  $$$$$$$')
                                else:
                                    print('$$$$  SYSTEM WON THE MATCH  $$$$$$$$$$')
                                break 
                        break  
                break
                
            elif bat_ball == 2:
                while True:
                   
                    run = random.randint(1,6)
                    ball_3 = int(input('throw ball :- '))
                    print("system hit :- {}".format(run))
                    run_res2 += run 
                    print("system'S TOTAL RUN :- {}".format(run_res2))
                    if run == ball_3:
                        print('.................SYSTEM WICKET.............')
                        
                        print("now its user turn to bat") 
                        while True:
                           
                            ball_2 = random.randint(1,6)
                            run = int(input('HIT RUN   :- '))
                            print(ball_2)
                            run_res3 += run 
                            print("USER'S TOTAL RUN :- {}".format(run_res3))
                            if run == ball_2:
                                print('...........USER WICKET.............')
                                print("END OF THE MATCH")
                                if run_res2 > run_res3:
                                    print(' $$$$$$$ SYSTEM WON THE MATCH  $$$$$$$')
                                else:
                                    print('$$$$  USER WON THE MATCH  $$$$$$$$$$')

                                break
                        break
            
                break
                
            else:
                print('***** ENTER PROPER KEY ******')               
    else:
        print('systems chose to ball first')
        while True:
    
            ball_5 = random.randint(1,6)
            run = int(input('HIT RUN   :- '))
            print(ball_5)
            run_res4 += run 
            print("USER'S TOTAL RUN :- {}".format(run_res4))
            if run == ball_5:
                print('...........USER WICKET.............')
                
                print("now its system turn to bat ")
                while True:
                  
                    run = random.randint(1,6)
                    ball_3 = int(input('throw ball :- '))
                    print("system hit :- {}".format(run))
                    run_res5 += run 
                    print("SYSTEM'S TOTAL RUN :- {}".format(run_res5))
                    if run == ball_3:
                        print('.................SYSTEM WICKET.............')
                        print("END OF THE MATCH")
                        if run_res4 > run_res5:
                            print(' $$$$$$$  USER  WON THE MATCH  $$$$$$$')
                        else:
                            print('$$$$ SYSTEM WON THE MATCH  $$$$$$$$$$')
                        break  
                break
    again = input("DO YOU WANT TO PLAY AGAIN press (Y) for yes (N) for no:- ")
    if again == 'n':
        print('--------------THANK YOU FOR PLAYING HAVE A GOOD DAY------------------ :)')

        break
