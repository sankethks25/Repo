# %%
import pandas as pd

# %%
data = pd.read_csv("E:/testfiles/business.csv",header = None,names = ['a','b','c','d','e'],skiprows=[2,3])

# %%
h = data.head(5)
t = data.tail()

# %%
h.to_csv("tes1.csv",index=False,header=False,sep="#",columns = ['reference','Description','Period','Previously published','Revised'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-488c42d45190> in <module>
# ----> 1 h.to_csv("tes1.csv",index=False,header=False,sep="#",columns = ['reference','Description','Period','Previously published','Revised'])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ...

# %%
pd.read_csv("tes1.csv")
# Out:
#   PPIQ.SQU900000#PPI output index - All industries #2020.06#1183#1184
# 0  PPIQ.SQU900001#PPI output index - All industri...
# 1  PPIQ.SQUC76745#PPI published output commodity ...
# 2  PPIQ.SQUCC3100#PPI output index level 3 - Wood...
# 3  PPIQ.SQUCC3110#PPI output index level 4 - Wood...

# %%
data
# Out:
#                    a                                                  b  \
# 0   Series reference                                        Description
# 1     PPIQ.SQU900000                 PPI output index - All industries
# 2     PPIQ.SQUCC3100  PPI output index level 3 - Wood product manufa...
# 3     PPIQ.SQUCC3110  PPI output index level 4 - Wood product manufa...
# 4     PPIQ.SQUFF0000         PPI output index level 1 - Wholesale trade
# ..               ...                                                ...
# 72    PPIQ.SQNMN2100  PPI input index level 3 - Administrative and s...
# 73    PPIQ.SQNRS211X     PPI input index level 4 - Repair & maintenance
# 74        FPIQ.SEC14  Farm expenses price index - Dairy farms - Freight
# 75        FPIQ.SEC99  Farm expenses price index - Dairy farms - All ...
# 76        FPIQ.SEH14    Farm expenses price index - All farms - Freight
#
#           c                     d        e
# 0    Period  Previously published  Revised
# ...

# %%
data1 = pd.read_csv("E:/testfiles/business.csv",skiprows=[2,3],na_values=[1184],index_)

# %%
data1
# Out:
#    Series reference                                        Description  \
# 0    PPIQ.SQU900000                 PPI output index - All industries
# 1    PPIQ.SQUCC3100  PPI output index level 3 - Wood product manufa...
# 2    PPIQ.SQUCC3110  PPI output index level 4 - Wood product manufa...
# 3    PPIQ.SQUFF0000         PPI output index level 1 - Wholesale trade
# 4    PPIQ.SQUFF1000         PPI output index level 2 - Wholesale trade
# ..              ...                                                ...
# 71   PPIQ.SQNMN2100  PPI input index level 3 - Administrative and s...
# 72   PPIQ.SQNRS211X     PPI input index level 4 - Repair & maintenance
# 73       FPIQ.SEC14  Farm expenses price index - Dairy farms - Freight
# 74       FPIQ.SEC99  Farm expenses price index - Dairy farms - All ...
# 75       FPIQ.SEH14    Farm expenses price index - All farms - Freight
#
#      Period  Previously published  Revised
# 0   2020.06                  1183      NaN
# ...

# %%
data1.describe()
# Out:
#              Period  Previously published      Revised
# count  7.600000e+01             76.000000    75.000000
# mean   2.020060e+03           1153.763158  1159.306667
# std    1.602191e-12             78.770531    88.948964
# min    2.020060e+03            903.000000   904.000000
# 25%    2.020060e+03           1123.000000  1125.000000
# 50%    2.020060e+03           1150.000000  1151.000000
# 75%    2.020060e+03           1190.250000  1193.500000
# max    2.020060e+03           1415.000000  1568.000000

# %%
data1.dtypes
# Out:
# Series reference         object
# Description              object
# Period                  float64
# Previously published      int64
# Revised                 float64
# dtype: object

# %%
data1['Period']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-517d51b7a8a4> in <module>
# ----> 1 data1['Period']
#
# NameError: name 'data1' is not defined

# %%
df = pd.read_excel("E:/testfiles/excel.xls")

# %%
df.head()
# Out:
#    Unnamed: 0 First Name  Last Name  Gender        Country  Age        Date  \
# 0           1      Dulce      Abril  Female  United States   32  15/10/2017
# 1           2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016
# 2           3     Philip       Gent    Male         France   36  21/05/2015
# 3           4   Kathleen     Hanner  Female  United States   25  15/10/2017
# 4           5    Nereida    Magwood  Female  United States   58  16/08/2016
#
#      Id
# 0  1562
# 1  1582
# 2  2587
# 3  3549
# 4  2468

# %%
dfh = pd.read_html("https://en.wikipedia.org/wiki/Python_(programming_language)")

# %%
dfh[6]
# Out:
#               0                                                  1
# 0  Audio-visual  AlexNet WaveNet Human image synthesis HWR OCR ...
# 1        Verbal  Word2vec Transformer BERT NMT Project Debater ...
# 2    Decisional  AlphaGo Q-learning SARSA OpenAI Five Self-driv...

# %%
type(dfh)
# Out:
# list

# %%
import requests
import json
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
res = requests.get(url)
js = res.json()

# %%
for i in range(len(js)):
    print(js[i]['html_url'])
# Out:
# https://github.com/pandas-dev/pandas/pull/42290
# https://github.com/pandas-dev/pandas/pull/42289
# https://github.com/pandas-dev/pandas/pull/42288
# https://github.com/pandas-dev/pandas/issues/42287
# https://github.com/pandas-dev/pandas/issues/42286
# https://github.com/pandas-dev/pandas/pull/42285
# https://github.com/pandas-dev/pandas/pull/42284
# https://github.com/pandas-dev/pandas/pull/42278
# https://github.com/pandas-dev/pandas/issues/42276
# https://github.com/pandas-dev/pandas/issues/42275
# https://github.com/pandas-dev/pandas/pull/42274
# https://github.com/pandas-dev/pandas/pull/42273
# https://github.com/pandas-dev/pandas/issues/42272
# https://github.com/pandas-dev/pandas/pull/42271
# https://github.com/pandas-dev/pandas/pull/42269
# https://github.com/pandas-dev/pandas/pull/42267
# https://github.com/pandas-dev/pandas/pull/42265
# https://github.com/pandas-dev/pandas/pull/42264
# https://github.com/pandas-dev/pandas/pull/42263
# ...

# %%
pd.DataFrame(js,columns = ['title','html_url'])
# Out:
#                                                 title  \
# 0   DOC: Only include numpy.std note for std, not ...
# 1             BUG: get_indexer_non_unique with np.nan
# 2   DEPR: treating dt64 as UTC in Timestamp constr...
# 3   BUG: expanding numba functions being cached wi...
# 4       REGR: ExcelWriter fails when supplying kwargs
# 5      to_timedelta docs warning on default behaviour
# 6   TST: move custom business month tests to own f...
# 7   TST: Added test for upcasting to object when c...
# 8   BUG: `Styler.to_excel` does not export styles ...
# 9   ENH: groupby.max() should not cast int to int6...
# 10           ⬆️ UPGRADE: Autoupdate pre-commit config
# 11             ENH: Add `method='table'` for EWM.mean
# 12  BUG: false negatives for multiindex joins vali...
# 13     CLN: simplify Styler clear mechanics and tests
# 14                    DEPR: Index.get_loc with method
# 15      TST IntegerArray bounds error closing GH21796
# ...

# %%
data = pd.read_csv("E:/ML-DATASETS/train.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data[data.dtypes[data.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[['Age']]
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
pd.DataFrame(data,columns =['Age'])
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
data["Ticket"][5:16]
# Out:
# 5        330877
# 6         17463
# 7        349909
# 8        347742
# 9        237736
# 10      PP 9549
# 11       113783
# 12    A/5. 2151
# 13       347082
# 14       350406
# 15       248706
# Name: Ticket, dtype: object

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data['san'] = "s"

# %%
data[['san']]
# Out:
#     san
# 0     s
# 1     s
# 2     s
# 3     s
# 4     s
# ..   ..
# 886   s
# 887   s
# 888   s
# 889   s
# 890   s
#
# [891 rows x 1 columns]

# %%
pd.Categorical(data['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
data["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
i = data['Cabin'][data['Cabin'].isnull() == False].index

# %%
data.iloc[i]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data["Cabin"]
# Out:
# nan

# %%
[data['Cabin'].isnull() == False]
# Out:
# [0      False
#  1       True
#  2      False
#  3       True
#  4      False
#         ...
#  886    False
#  887     True
#  888    False
#  889     True
#  890    False
#  Name: Cabin, Length: 891, dtype: bool]

# %%
data["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
# Out:
# 512.3292

# %%
data[data["Fare"] == max(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked san
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C   s
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C   s
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C   s

# %%
data[data["Fare"] == 512.3292]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked san
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C   s
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C   s
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C   s

# %%
i = data["Fare"] == 512.3292

# %% [markdown]
# ## Chipotle Data Set

# %%
import pandas as pd
df = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.sort_values(by = "item_price")
# Out:
#       order_id  quantity            item_name  \
# 261        113         1          Canned Soda
# 1805       730         1          Canned Soda
# 1030       424         1          Canned Soda
# 3020      1201         1          Canned Soda
# 3021      1201         1        Bottled Water
# ...        ...       ...                  ...
# 4547      1807         1     Steak Salad Bowl
# 4391      1752         1     Steak Salad Bowl
# 2600      1032         1     Steak Salad Bowl
# 4241      1693         1     Steak Salad Bowl
# 4390      1751         1  Barbacoa Salad Bowl
#
#                                      choice_description item_price
# 261                                      [Mountain Dew]     $1.09
# 1805                                           [Sprite]     $1.09
# 1030                                  [Diet Dr. Pepper]     $1.09
# 3020                                  [Diet Dr. Pepper]     $1.09
# 3021                                                NaN     $1.09
# ...

# %%
df["item_price"][0] = "10"
# Out:
# <ipython-input-221-5a38327a051c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["item_price"][0] = "10"

# %%
df.iloc[1]["item_price"]
# Out:
# '$3.39 '

# %%
type(eval("[1]"))
# Out:
# list

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN         10
# ...

# %%
"k"
# Out:
# 'k'

# %%
eval(str(1))
# Out:
# 1

# %%
l = [1,4,2,3]

# %%
print(l.sort())
# Out:
# None

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
import pandas as pd

# %%
data = [['mejastic', "KSL"], ['mejastic', "Electonic city"], ['juli', 14]]

# %%
df = pd.DataFrame(data, columns = ['from', 'to'])

# %%
 details = {"Majastic_ksl": {"MKSL1":"10:00 AM","MKSL2":"11:00","MKSL3":"12:00"}, "Majastic_uttarahalli": {"MU1":"10:00 AM","MU2":"11:00","MU3":"12:00"}, "Majastic_kengeri": {"MK1":"10:00 AM","MK2":"11:00","MK3":"12:00"},
                   "electroniccity_ksl": {"EKSL1":"2:00 PM","EKSL2":"2:30 PM","EKSL3":"2:30 PM"}, "electroniccity_uttarahalli": {"EU1":"2:30 PM","EU2":"2:30 PM","EU3":"2:30 PM"}, "electroniccity_kengeri": {"EK1":"2:30 PM","EK2":"2:30 PM","EK3":"2:30 PM"},
                   "silkboard_kengeri": {"SK1":"2:00 PM","SK2":"2:30 PM","SK3":"2:30 PM"}, "silkboard_ksl": {"SKSL1":"10:00 AM","SKSL2":"11:00","SKSL2":"12:00"}, "silkboard_uttarahalli": {"SU1":"10:00 AM","SU2":"11:00","SU3":"12:00"}
                   }

# %%
d = details.get('Majastic_ksl')

# %%
d
# Out:
# {'MKSL1': '10:00 AM', 'MKSL2': '11:00', 'MKSL3': '12:00'}

# %%
for key,value in d.items():
    print(key)
# Out:
# MKSL1
# MKSL2
# MKSL3

# %%
def insert(number, name, age, gender,route):
    query = "INSERT INTO buspass.passanger(number,name,age,gender,route) values({},{},{},{},{});".format(number,name,age,gender,route)
    print(query)

# %%
 insert(8277337162,'sanketh',23,"male", {"source": "KSL", "destination":"mejastic"})
# Out:
# INSERT INTO buspass.passanger(number,name,age,gender,route) values(8277337162,sanketh,23,male,{'source': 'KSL', 'destination': 'mejastic'});

# %%
def insert(number, name, age, gender, route):
        temp = {"number":number,"name":name,"age":age,"gender":gender,"route":route}
        for data in temp:
            print(data["name"])

# %%
insert(8277337162, 'sanketh', 23, 'male', {'source': 'KSL', 'destination': 'mejastic'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-2bd23eec8479> in <module>
# ----> 1 insert(8277337162, 'sanketh', 23, 'male', {'source': 'KSL', 'destination': 'mejastic'})
#
# <ipython-input-58-20dd6c7bb317> in insert(number, name, age, gender, route)
#       2         temp = {"number":number,"name":name,"age":age,"gender":gender,"route":route}
#       3         for data in range(len(temp)):
# ----> 4             print((temp[data]))
#
# KeyError: 0

# %%
d = {"num":1111111}

# %%
d["num"]
# Out:
# 1111111

# %%
 temp = [{"number":123444,"name":"san","age":12,"gender":"male","route": {'source': 'KSL', 'destination': 'mejastic'}}]

# %%
temp
# Out:
# {'number': 123444,
#  'name': 'san',
#  'age': 12,
#  'gender': 'male',
#  'route': {'source': 'KSL', 'destination': 'mejastic'}}

# %%
for i in temp:
    print(i['number'])
# Out:
# 123444

# %%
def a():
    return b(),c()

# %%
def b():
    print("hai")
    
def c():
    print("hello")

# %%
a()
# Out:
# hai
# hello
# (None, None)

# %%
len("So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And /n although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and /n spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a /n very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep /n every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s  /n not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have /n a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve  /n suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we /n can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered \n as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this /n is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not /n going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can /n do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it /n will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the /n next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a /n firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be /n making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime /n in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare /n families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out these initiatives. We’ll be making sure that people have a very clear /n understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun  /n out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the wrong people So over the next several days, we’ll be rolling out /n  these initiatives. We’ll be making sure that people have a very clear understanding of what can make a difference and what we can do. And although we have to be very clear that this is not going to solve every violent crime in this country, it’s not going to prevent every mass shooting, it’s not going to keep every gun out of the hands of a criminal, it will potentially save lives and spare families the pain and the extraordinary loss that they’ve suffered as a consequence of a firearm getting in the hands of the /n wrong people")
# Out:
# 12916

# %%
l = ["sdsd","sdsdsd",'dsadadsa']

# %%
def fun(p):
    i =1
    print(p[i])

# %%
fun(l)
# Out:
# sdsdsd
