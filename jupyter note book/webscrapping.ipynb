# %%
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import requests

# %%
url = "https://www.flipkart.com/search?q=" +"iphone7"

# %%
r =uReq(url)
r

# %%
flipkart = r.read()
flipkart
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.7570a9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="app
# ...

# %%
r.close()

# %%
flip_html = bs(flipkart, "html.parser")

# %%
flip_html
# Out:
# <!DOCTYPE html>
# ...

# %%
mainBox = flip_html.find_all("div",{"class" : "_1AtVbE col-12-12"})

# %%
firstBox = mainBox[2]
firstBox
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBEMK62E7YZEVZ8" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-7-black-128-gb/p/itmen6daqhtbuzhj?pid=MOBEMK62E7YZEVZ8&amp;lid=LSTMOBEMK62E7YZEVZ8G5MHLF&amp;marketplace=FLIPKART&amp;q=iphone7&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=f25e67ae-60a3-4868-b44a-a07e31dce903.MOBEMK62E7YZEVZ8.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=mwhdtdnmhc0000001631172052302&amp;qH=c848b7081ba96a14" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 7 (Black, 128 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/k12go7k0/mobile/7/e/e/apple-iphone-7-mn8x2hn-a-original-imafkqcqhzxuvcpd.jpeg?q=70"/></div></div><div class="_3G6awp"><span class="_192laR">Currently unavailable</span></div></div><div class="_3wLduG"><div class="_3PzNI-"
# ...

# %%
ref = firstBox.div.div.div.a["href"]

# %%
ref
# Out:
# '/apple-iphone-7-black-128-gb/p/itmen6daqhtbuzhj?pid=MOBEMK62E7YZEVZ8&lid=LSTMOBEMK62E7YZEVZ8G5MHLF&marketplace=FLIPKART&q=iphone7&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=f25e67ae-60a3-4868-b44a-a07e31dce903.MOBEMK62E7YZEVZ8.SEARCH&ppt=None&ppn=None&ssid=mwhdtdnmhc0000001631172052302&qH=c848b7081ba96a14'

# %%
for i in mainBox[2:-3]:
    print(i.div.div.div.a["href"])
# Out:
# /apple-iphone-7-black-128-gb/p/itmen6daqhtbuzhj?pid=MOBEMK62E7YZEVZ8&lid=LSTMOBEMK62E7YZEVZ8G5MHLF&marketplace=FLIPKART&q=iphone7&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=f25e67ae-60a3-4868-b44a-a07e31dce903.MOBEMK62E7YZEVZ8.SEARCH&ppt=None&ppn=None&ssid=mwhdtdnmhc0000001631172052302&qH=c848b7081ba96a14
# /apple-iphone-7-red-128-gb/p/itmesttfr5f5pgux?pid=MOBESTTFAZYQGYG9&lid=LSTMOBESTTFAZYQGYG9QBJJPI&marketplace=FLIPKART&q=iphone7&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=f25e67ae-60a3-4868-b44a-a07e31dce903.MOBESTTFAZYQGYG9.SEARCH&ppt=None&ppn=None&ssid=mwhdtdnmhc0000001631172052302&qH=c848b7081ba96a14
# /apple-iphone-7-silver-32-gb/p/itmen6dawz2g5dry?pid=MOBEMK62HSQDSGGF&lid=LSTMOBEMK62HSQDSGGFKX5AY0&marketplace=FLIPKART&q=iphone7&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=f25e67ae-60a3-4868-b44a-a07e31dce903.MOBEMK62HSQDSGGF.SEARCH&ppt=None&ppn=None&ssid=mwhdtdnmhc0000001631172052302&qH=c848b7081ba96a14
# ...

# %%
productLink = "https://www.flipkart.com" + ref

# %%
productLink
# Out:
# 'https://www.flipkart.com/apple-iphone-7-black-128-gb/p/itmen6daqhtbuzhj?pid=MOBEMK62E7YZEVZ8&lid=LSTMOBEMK62E7YZEVZ8G5MHLF&marketplace=FLIPKART&q=iphone7&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=f25e67ae-60a3-4868-b44a-a07e31dce903.MOBEMK62E7YZEVZ8.SEARCH&ppt=None&ppn=None&ssid=mwhdtdnmhc0000001631172052302&qH=c848b7081ba96a14'

# %%
#both are same
req1 = uReq(productLink)
prodOne = req1.read()
prodOne_Html = bs(prodOne,"html.parser")

# %%
#both are same
prodOne = requests.get(productLink)
prodOne.encoding = 'utf-8'
prodOne_Html =  bs(prodOne.text,"html.parser")

# %%
AllReviews = prodOne_Html.find_all("div",{"class":"_16PBlm"})

# %%
AllReviews
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Worth every penny</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Thank u Flipkart for your fast delivery. It is awesome and very very nice.I like this very much.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201909/blobio-imr-201909_bb63f44c74f24bd3a46d806bfe7b7d01.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-201909/blobio-imr-201909_c076f56308954ddba89a8f889c733848.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR
# ...

# %%
name = AllReviews[0].div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text

# %%
for i in AllReviews[0:4]:
    print(i.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Hemanta Sa
# Ezzazuddin Huseni
# suresh b
# Flipkart Customer

# %%
contents = AllReviews[0].div.div.find_all("div",{"class":"t-ZTKy"})
contents
# Out:
# [<div class="t-ZTKy"><div><div class="">Thank u Flipkart for your fast delivery. It is awesome and very very nice.I like this very much.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>]

# %%
contents[0].div.div.text
# Out:
# 'Thank u Flipkart for your fast delivery. It is awesome and very very nice.I like this very much.'
