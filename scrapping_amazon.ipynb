# %%
from bs4 import BeautifulSoup
import requests
data = requests.get("https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&as-backfill=on").text
model =[]
cost = []
offer = []
config = []

# %%
soup =BeautifulSoup(data,"lxml")

# %%
for i in (soup.find_all("a",href = True ,class_="_1fQZEK")):
    print(i.find("div",class_="_4rR01T").text)
    print(i.find("div",class_="_30jeq3 _1_WHN1").text)
    print(i.find("div",class_="_3Ay6Sb"))
    
    
    #for c in (soup.find_all("ul",class_="_1xgFaf")):
     #   config.append(c.find("li",class_="rgWa7D"))
# Out:
# Lenovo Ideapad Slim 5i Core i5 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/2 GB Graphics) 15I...
# ₹70,990
# <div class="_3Ay6Sb"><span>30% off</span></div>
# Lenovo Ideapad Gaming 3 Ryzen 7 Octa Core 4800H - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graph...
# ₹72,990
# <div class="_3Ay6Sb"><span>25% off</span></div>
# HP 14s Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14s-cf3074TU Thin and Light Laptop
# ₹35,990
# <div class="_3Ay6Sb"><span>7% off</span></div>
# Lenovo ThinkPad Core i5 10th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) ThinkPad E14 Thin and Li...
# ₹59,990
# <div class="_3Ay6Sb"><span>10% off</span></div>
# HP 14s Ryzen 5 Quad Core 3450U - (8 GB/512 GB SSD/Windows 10 Home) 14s-fr0012AU Thin and Light Laptop
# ₹44,190
# <div class="_3Ay6Sb"><span>11% off</span></div>
# HP 14s Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) 14s-DR2006TU Thin and Light Laptop
# ₹58,990
# <div class="_3Ay6Sb"><span>2% off</span></div>
# ...

# %%
for i in offer:
    print(i)
# Out:
# <div class="_3Ay6Sb"><span>30% off</span></div>
# <div class="_3Ay6Sb"><span>25% off</span></div>
# <div class="_3Ay6Sb"><span>7% off</span></div>
# <div class="_3Ay6Sb"><span>10% off</span></div>
# <div class="_3Ay6Sb"><span>11% off</span></div>
# <div class="_3Ay6Sb"><span>2% off</span></div>
# <div class="_3Ay6Sb"><span>18% off</span></div>
# <div class="_3Ay6Sb"><span>11% off</span></div>
# <div class="_3Ay6Sb"><span>13% off</span></div>
# <div class="_3Ay6Sb"><span>18% off</span></div>
# <div class="_3Ay6Sb"><span>25% off</span></div>
# <div class="_3Ay6Sb"><span>18% off</span></div>
# <div class="_3Ay6Sb"><span>33% off</span></div>
# <div class="_3Ay6Sb"><span>19% off</span></div>
# <div class="_3Ay6Sb"><span>24% off</span></div>
# <div class="_3Ay6Sb"><span>7% off</span></div>
# <div class="_3Ay6Sb"><span>13% off</span></div>
# <div class="_3Ay6Sb"><span>2% off</span></div>
# <div class="_3Ay6Sb"><span>15% off</span></div>
# <div class="_3Ay6Sb"><span>6% off</span></div>
# ...

# %%
for i in config:
    print(i)
# Out:
# <li class="rgWa7D">Intel Core i5 Processor (11th Gen)</li>
# <li class="rgWa7D">AMD Ryzen 7 Octa Core Processor</li>
# <li class="rgWa7D">Intel Core i3 Processor (10th Gen)</li>
# <li class="rgWa7D">Intel Core i5 Processor (10th Gen)</li>
# <li class="rgWa7D">AMD Ryzen 5 Quad Core Processor</li>
# <li class="rgWa7D">Intel Core i5 Processor (11th Gen)</li>
# <li class="rgWa7D">Intel Core i3 Processor (10th Gen)</li>
# <li class="rgWa7D">Intel Core i7 Processor (10th Gen)</li>
# <li class="rgWa7D">Intel Core i7 Processor (10th Gen)</li>
# <li class="rgWa7D">Intel Core i7 Processor (8th Gen)</li>
# <li class="rgWa7D">Intel Core i5 Processor (9th Gen)</li>
# <li class="rgWa7D">Intel Core i5 Processor (9th Gen)</li>
# <li class="rgWa7D">Intel Core i5 Processor (10th Gen)</li>
# <li class="rgWa7D">Intel Core i7 Processor (9th Gen)</li>
# <li class="rgWa7D">Intel Core i7 Processor (10th Gen)</li>
# <li class="rgWa7D">60 Hz Refresh Rate- It can display upto 60 frames per second.</li>
# ...

# %%
# Out:
# 5
# 1 2 3 4 1
# found
